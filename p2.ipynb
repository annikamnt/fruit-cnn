# %%
import cv2
import os
import shutil

# Root folders
original_root = "OriginalImage"
output_root = "ColorVariants"

# Variants
variants = ["Original", "Grayscale", "Swap", "Red", "Green", "Blue"]

# Image size
img_size = (128, 128)

def pad_to_square(img):
    h, w = img.shape[:2]
    max_dim = max(h, w)

    # Amount of padding needed
    top = (max_dim - h) // 2
    bottom = max_dim - h - top
    left = (max_dim - w) // 2
    right = max_dim - w - left

    # Replicate nearest pixel outward
    padded = cv2.copyMakeBorder(
        img,
        top, bottom, left, right,
        borderType = cv2.BORDER_REPLICATE
    )

    return padded

# ---------------------------------------------------------
# 1. Clear output_root entirely, then recreate it
# ---------------------------------------------------------
if os.path.exists(output_root):
    shutil.rmtree(output_root)

for v in variants:
    os.makedirs(os.path.join(output_root, v), exist_ok=True)

# ---------------------------------------------------------
# 2. Process per variant
# ---------------------------------------------------------
for variant in variants:
    variant_path = os.path.join(output_root, variant)

    for class_name in os.listdir(original_root):
        class_src = os.path.join(original_root, class_name)
        class_dst = os.path.join(variant_path, class_name)
        os.makedirs(class_dst, exist_ok=True)

        # Get sorted list of images to ensure consistent first 50 selection
        images = sorted(os.listdir(class_src))
        images = images[:50]   # Take only the first 50

        for img_name in images:
            img_path = os.path.join(class_src, img_name)
            img = cv2.imread(img_path)

            # ----------- Square padding then resizing -----------
            squared = pad_to_square(img)
            img_resized = cv2.resize(squared, img_size)

            # ---------------- Variant Conversions ---------------- #

            if variant == "Original":
                converted = img_resized

            elif variant == "Grayscale":
                gray = cv2.cvtColor(img_resized, cv2.COLOR_BGR2GRAY)
                converted = cv2.cvtColor(gray, cv2.COLOR_GRAY2BGR)

            elif variant == "Swap":
                b, g, r = cv2.split(img_resized)
                converted = cv2.merge([r, g, b])

            elif variant == "Red":
                b, g, r = cv2.split(img_resized)
                converted = cv2.merge([b*0, g*0, r])

            elif variant == "Green":
                b, g, r = cv2.split(img_resized)
                converted = cv2.merge([b*0, g, r*0])

            elif variant == "Blue":
                b, g, r = cv2.split(img_resized)
                converted = cv2.merge([b, g*0, r*0])

            # ----------------------------------------------------- #

            out_path = os.path.join(class_dst, img_name)
            cv2.imwrite(out_path, converted)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

aug = ImageDataGenerator(
    rotation_range = 20,
    width_shift_range = 0.1,
    height_shift_range = 0.1,
    shear_range = 0.15,
    zoom_range = 0.15,
    horizontal_flip = True,
    fill_mode = 'nearest'
)

train_datagen = ImageDataGenerator(
    validation_split=0.2,  # 80/20 split
    **{k: v for k, v in aug.__dict__.items() if k in ["rotation_range", "width_shift_range",
                                                      "height_shift_range", "shear_range",
                                                      "zoom_range", "horizontal_flip",
                                                      "fill_mode"]}
)

batch_size = 32

train_gen = train_datagen.flow_from_directory(
    original_root,
    target_size = img_size,
    class_mode = "categorical",
    batch_size = batch_size,
    subset = "training"
)

val_gen = train_datagen.flow_from_directory(
    original_root,
    target_size = img_size,
    class_mode = "categorical",
    batch_size = batch_size,
    subset = "validation"
)
# Out:
# Found 2560 images belonging to 16 classes.
# Found 640 images belonging to 16 classes.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

def build_model(num_classes):
    model = Sequential([
        Conv2D(32, (3, 3), activation = 'relu', input_shape = (128, 128, 3)),
        MaxPooling2D(2, 2),

        Conv2D(64, (3, 3), activation = 'relu'),
        MaxPooling2D(2, 2),

        Conv2D(128, (3, 3), activation = 'relu'),
        MaxPooling2D(2, 2),

        Flatten(),
        Dense(128, activation = 'relu'),
        Dropout(0.4),
        Dense(num_classes, activation = 'softmax')
    ])

    model.compile(
        optimizer = "adam",
        loss = "categorical_crossentropy",
        metrics = ["accuracy"]
    )
    return model

# %%
import os

variants = [
    "ColorVariants/Original",
    "ColorVariants/Grayscale",
    "ColorVariants/Swap",
    "ColorVariants/Red",
    "ColorVariants/Green",
    "ColorVariants/Blue"
]

for variant_path in variants:
    train_gen = train_datagen.flow_from_directory(
        variant_path,
        target_size=img_size,
        class_mode="categorical",
        batch_size=batch_size,
        subset="training"
    )
    val_gen = train_datagen.flow_from_directory(
        variant_path,
        target_size=img_size,
        class_mode="categorical",
        batch_size=batch_size,
        subset="validation"
    )

    model = build_model(num_classes = train_gen.num_classes)

    history = model.fit(
        train_gen,
        validation_data = val_gen,
        epochs = 20
    )

    model.save(f"cnn_{os.path.basename(variant_path)}.keras")
# Out:
# Found 640 images belonging to 16 classes.
# Found 160 images belonging to 16 classes.
# c:\Users\user\anaconda3\lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\user\anaconda3\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 23s 1s/step - accuracy: 0.0541 - loss: 75.1567 - val_accuracy: 0.1875 - val_loss: 2.4823
# Epoch 2/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 406ms/step - accuracy: 0.1728 - loss: 2.5444 - val_accuracy: 0.2000 - val_loss: 2.4348
# Epoch 3/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 448ms/step - accuracy: 0.2150 - loss: 2.3586 - val_accuracy: 0.2750 - val_loss: 2.0928
# Epoch 4/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 472ms/step - accuracy: 0.2886 - loss: 2.1171 - val_accuracy: 0.2125 - val_loss: 2.4311
# Epoch 5/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 458ms/step - accuracy: 0.2271 - loss: 2.3308 - val_accuracy: 0.3500 - val_loss: 2.0257
# Epoch 6/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 393ms/step - accuracy: 0.3134 - loss: 2.0650 - val_accuracy: 0.3000 - val_loss: 2.0844
# Epoch 7/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 447ms/step - accuracy: 0.2746 - loss: 2.4447 - val_accuracy: 0.2937 - val_loss: 2.1013
# Epoch 8/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 447ms/step - accuracy: 0.3656 - loss: 1.9048 - val_accuracy: 0.3125 - val_loss: 1.8943
# Epoch 9/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 421ms/step - accuracy: 0.3974 - loss: 1.7696 - val_accuracy: 0.3938 - val_loss: 1.7882
# Epoch 10/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 467ms/step - accuracy: 0.4204 - loss: 1.6990 - val_accuracy: 0.3938 - val_loss: 1.6886
# Epoch 11/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 486ms/step - accuracy: 0.4515 - loss: 1.6427 - val_accuracy: 0.4563 - val_loss: 1.6011
# Epoch 12/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 430ms/step - accuracy: 0.4677 - loss: 1.6094 - val_accuracy: 0.4437 - val_loss: 1.7179
# Epoch 13/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 422ms/step - accuracy: 0.5012 - loss: 1.5084 - val_accuracy: 0.4500 - val_loss: 1.5635
# Epoch 14/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 447ms/step - accuracy: 0.5254 - loss: 1.3943 - val_accuracy: 0.4688 - val_loss: 1.6424
# Epoch 15/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 477ms/step - accuracy: 0.4664 - loss: 1.6373 - val_accuracy: 0.4437 - val_loss: 1.5937
# Epoch 16/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 444ms/step - accuracy: 0.5234 - loss: 1.3700 - val_accuracy: 0.4000 - val_loss: 1.7154
# Epoch 17/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 472ms/step - accuracy: 0.5106 - loss: 1.5935 - val_accuracy: 0.4313 - val_loss: 1.6966
# Epoch 18/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 461ms/step - accuracy: 0.4651 - loss: 1.6191 - val_accuracy: 0.5750 - val_loss: 1.4541
# Epoch 19/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 409ms/step - accuracy: 0.5925 - loss: 1.2994 - val_accuracy: 0.5312 - val_loss: 1.4483
# Epoch 20/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 444ms/step - accuracy: 0.6066 - loss: 1.1850 - val_accuracy: 0.5312 - val_loss: 1.5092
# Found 640 images belonging to 16 classes.
# Found 160 images belonging to 16 classes.
# Epoch 1/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 22s 984ms/step - accuracy: 0.0676 - loss: 67.6468 - val_accuracy: 0.0625 - val_loss: 2.7732
# Epoch 2/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 383ms/step - accuracy: 0.0747 - loss: 2.8240 - val_accuracy: 0.0625 - val_loss: 2.7726
# Epoch 3/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 380ms/step - accuracy: 0.0620 - loss: 2.7736 - val_accuracy: 0.0625 - val_loss: 2.7726
# Epoch 4/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 385ms/step - accuracy: 0.0752 - loss: 2.7729 - val_accuracy: 0.0625 - val_loss: 2.7726
# Epoch 5/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 394ms/step - accuracy: 0.0646 - loss: 2.7726 - val_accuracy: 0.0625 - val_loss: 2.7726
# Epoch 6/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 389ms/step - accuracy: 0.0631 - loss: 2.7725 - val_accuracy: 0.0625 - val_loss: 2.7726
# Epoch 7/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 395ms/step - accuracy: 0.0713 - loss: 2.7727 - val_accuracy: 0.0625 - val_loss: 2.7726
# Epoch 8/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 389ms/step - accuracy: 0.0498 - loss: 2.7729 - val_accuracy: 0.0625 - val_loss: 2.7726
# Epoch 9/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 385ms/step - accuracy: 0.0561 - loss: 2.7726 - val_accuracy: 0.0625 - val_loss: 2.7726
# Epoch 10/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 388ms/step - accuracy: 0.0576 - loss: 2.7726 - val_accuracy: 0.0625 - val_loss: 2.7726
# Epoch 11/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 383ms/step - accuracy: 0.0632 - loss: 2.7728 - val_accuracy: 0.0625 - val_loss: 2.7726
# Epoch 12/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 390ms/step - accuracy: 0.0589 - loss: 2.7726 - val_accuracy: 0.0625 - val_loss: 2.7726
# Epoch 13/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 390ms/step - accuracy: 0.0652 - loss: 2.7725 - val_accuracy: 0.0625 - val_loss: 2.7726
# Epoch 14/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 393ms/step - accuracy: 0.0821 - loss: 2.7722 - val_accuracy: 0.0625 - val_loss: 2.7726
# Epoch 15/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 393ms/step - accuracy: 0.0639 - loss: 2.7727 - val_accuracy: 0.0625 - val_loss: 2.7726
# Epoch 16/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 384ms/step - accuracy: 0.0590 - loss: 2.7727 - val_accuracy: 0.0625 - val_loss: 2.7726
# Epoch 17/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 380ms/step - accuracy: 0.0684 - loss: 2.7725 - val_accuracy: 0.0625 - val_loss: 2.7726
# Epoch 18/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 391ms/step - accuracy: 0.0576 - loss: 2.7726 - val_accuracy: 0.0625 - val_loss: 2.7726
# Epoch 19/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 398ms/step - accuracy: 0.0677 - loss: 2.7726 - val_accuracy: 0.0625 - val_loss: 2.7726
# Epoch 20/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 499ms/step - accuracy: 0.0753 - loss: 2.7728 - val_accuracy: 0.0625 - val_loss: 2.7726
# Found 640 images belonging to 16 classes.
# Found 160 images belonging to 16 classes.
# Epoch 1/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 21s 971ms/step - accuracy: 0.0895 - loss: 64.3182 - val_accuracy: 0.1187 - val_loss: 2.7662
# Epoch 2/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 391ms/step - accuracy: 0.1021 - loss: 2.7040 - val_accuracy: 0.1063 - val_loss: 2.6098
# Epoch 3/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 374ms/step - accuracy: 0.1073 - loss: 2.6945 - val_accuracy: 0.0625 - val_loss: 2.7726
# Epoch 4/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 372ms/step - accuracy: 0.0620 - loss: 2.7724 - val_accuracy: 0.0625 - val_loss: 2.7726
# Epoch 5/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 379ms/step - accuracy: 0.0614 - loss: 2.7726 - val_accuracy: 0.0625 - val_loss: 2.7726
# Epoch 6/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 386ms/step - accuracy: 0.0631 - loss: 2.7728 - val_accuracy: 0.0625 - val_loss: 2.7726
# Epoch 7/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 417ms/step - accuracy: 0.0601 - loss: 2.7725 - val_accuracy: 0.0625 - val_loss: 2.7726
# Epoch 8/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 363ms/step - accuracy: 0.0563 - loss: 2.7730 - val_accuracy: 0.0625 - val_loss: 2.7726
# Epoch 9/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 367ms/step - accuracy: 0.0623 - loss: 2.7728 - val_accuracy: 0.0625 - val_loss: 2.7726
# Epoch 10/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 369ms/step - accuracy: 0.0703 - loss: 2.7725 - val_accuracy: 0.0625 - val_loss: 2.7726
# Epoch 11/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 352ms/step - accuracy: 0.0711 - loss: 2.7723 - val_accuracy: 0.0625 - val_loss: 2.7726
# Epoch 12/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 362ms/step - accuracy: 0.0695 - loss: 2.7728 - val_accuracy: 0.0625 - val_loss: 2.7726
# Epoch 13/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 348ms/step - accuracy: 0.0795 - loss: 2.7728 - val_accuracy: 0.0625 - val_loss: 2.7726
# Epoch 14/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 350ms/step - accuracy: 0.0644 - loss: 2.7727 - val_accuracy: 0.0625 - val_loss: 2.7726
# Epoch 15/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 345ms/step - accuracy: 0.0677 - loss: 2.7726 - val_accuracy: 0.0625 - val_loss: 2.7726
# Epoch 16/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 342ms/step - accuracy: 0.0686 - loss: 2.7724 - val_accuracy: 0.0625 - val_loss: 2.7726
# Epoch 17/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 333ms/step - accuracy: 0.0673 - loss: 2.7727 - val_accuracy: 0.0625 - val_loss: 2.7726
# Epoch 18/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 334ms/step - accuracy: 0.0489 - loss: 2.7728 - val_accuracy: 0.0625 - val_loss: 2.7726
# Epoch 19/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 328ms/step - accuracy: 0.0594 - loss: 2.7726 - val_accuracy: 0.0625 - val_loss: 2.7726
# Epoch 20/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 331ms/step - accuracy: 0.0696 - loss: 2.7726 - val_accuracy: 0.0625 - val_loss: 2.7726
# Found 640 images belonging to 16 classes.
# Found 160 images belonging to 16 classes.
# Epoch 1/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 17s 794ms/step - accuracy: 0.0830 - loss: 42.5507 - val_accuracy: 0.0812 - val_loss: 2.7597
# Epoch 2/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 330ms/step - accuracy: 0.0549 - loss: 2.7412 - val_accuracy: 0.1625 - val_loss: 2.6342
# Epoch 3/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 325ms/step - accuracy: 0.1786 - loss: 2.6407 - val_accuracy: 0.1813 - val_loss: 2.4743
# Epoch 4/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 6s 323ms/step - accuracy: 0.1781 - loss: 2.5680 - val_accuracy: 0.1000 - val_loss: 2.5959
# Epoch 5/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 325ms/step - accuracy: 0.1695 - loss: 2.6503 - val_accuracy: 0.2188 - val_loss: 2.4878
# Epoch 6/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 6s 324ms/step - accuracy: 0.2080 - loss: 2.3821 - val_accuracy: 0.2562 - val_loss: 2.4874
# Epoch 7/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 6s 324ms/step - accuracy: 0.1785 - loss: 2.5385 - val_accuracy: 0.2500 - val_loss: 2.3950
# Epoch 8/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 6s 323ms/step - accuracy: 0.2406 - loss: 2.3552 - val_accuracy: 0.2125 - val_loss: 2.3789
# Epoch 9/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 6s 323ms/step - accuracy: 0.2661 - loss: 2.2184 - val_accuracy: 0.2188 - val_loss: 2.2353
# Epoch 10/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 348ms/step - accuracy: 0.2647 - loss: 2.2097 - val_accuracy: 0.2937 - val_loss: 2.2228
# Epoch 11/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 328ms/step - accuracy: 0.3015 - loss: 2.1835 - val_accuracy: 0.3438 - val_loss: 2.1246
# Epoch 12/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 328ms/step - accuracy: 0.3277 - loss: 2.0912 - val_accuracy: 0.3688 - val_loss: 2.1988
# Epoch 13/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 324ms/step - accuracy: 0.3865 - loss: 2.0512 - val_accuracy: 0.3438 - val_loss: 2.1024
# Epoch 14/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 325ms/step - accuracy: 0.3857 - loss: 2.0051 - val_accuracy: 0.2937 - val_loss: 2.1699
# Epoch 15/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 377ms/step - accuracy: 0.3747 - loss: 2.0318 - val_accuracy: 0.2937 - val_loss: 2.1375
# Epoch 16/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 350ms/step - accuracy: 0.4103 - loss: 1.8403 - val_accuracy: 0.3875 - val_loss: 1.9013
# Epoch 17/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 357ms/step - accuracy: 0.3981 - loss: 1.8795 - val_accuracy: 0.3688 - val_loss: 2.0340
# Epoch 18/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 355ms/step - accuracy: 0.3880 - loss: 2.0056 - val_accuracy: 0.3938 - val_loss: 1.9490
# Epoch 19/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 349ms/step - accuracy: 0.3817 - loss: 1.8508 - val_accuracy: 0.3438 - val_loss: 2.1943
# Epoch 20/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 328ms/step - accuracy: 0.3885 - loss: 2.0127 - val_accuracy: 0.3250 - val_loss: 2.1937
# Found 640 images belonging to 16 classes.
# Found 160 images belonging to 16 classes.
# Epoch 1/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 18s 829ms/step - accuracy: 0.0651 - loss: 62.2174 - val_accuracy: 0.1375 - val_loss: 2.7331
# Epoch 2/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 6s 321ms/step - accuracy: 0.1193 - loss: 2.6940 - val_accuracy: 0.1500 - val_loss: 2.5710
# Epoch 3/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 354ms/step - accuracy: 0.1706 - loss: 2.5233 - val_accuracy: 0.1625 - val_loss: 2.4402
# Epoch 4/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 377ms/step - accuracy: 0.1994 - loss: 2.4277 - val_accuracy: 0.2188 - val_loss: 2.3115
# Epoch 5/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 330ms/step - accuracy: 0.2679 - loss: 2.2751 - val_accuracy: 0.3063 - val_loss: 2.1175
# Epoch 6/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 332ms/step - accuracy: 0.3078 - loss: 2.1154 - val_accuracy: 0.3187 - val_loss: 2.0822
# Epoch 7/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 324ms/step - accuracy: 0.3073 - loss: 2.0642 - val_accuracy: 0.3562 - val_loss: 1.9885
# Epoch 8/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 329ms/step - accuracy: 0.3760 - loss: 2.0623 - val_accuracy: 0.3438 - val_loss: 1.9824
# Epoch 9/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 6s 324ms/step - accuracy: 0.3340 - loss: 1.9761 - val_accuracy: 0.3500 - val_loss: 1.9998
# Epoch 10/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 336ms/step - accuracy: 0.3703 - loss: 1.9993 - val_accuracy: 0.3938 - val_loss: 1.9012
# Epoch 11/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 6s 324ms/step - accuracy: 0.4327 - loss: 1.8483 - val_accuracy: 0.3688 - val_loss: 2.0188
# Epoch 12/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 326ms/step - accuracy: 0.4250 - loss: 1.8583 - val_accuracy: 0.3187 - val_loss: 2.0071
# Epoch 13/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 328ms/step - accuracy: 0.4574 - loss: 1.6074 - val_accuracy: 0.4313 - val_loss: 1.8590
# Epoch 14/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 329ms/step - accuracy: 0.4961 - loss: 1.6771 - val_accuracy: 0.4875 - val_loss: 1.7766
# Epoch 15/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 330ms/step - accuracy: 0.5193 - loss: 1.5293 - val_accuracy: 0.4625 - val_loss: 1.6157
# Epoch 16/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 383ms/step - accuracy: 0.4985 - loss: 1.5600 - val_accuracy: 0.5437 - val_loss: 1.5956
# Epoch 17/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 419ms/step - accuracy: 0.5081 - loss: 1.5344 - val_accuracy: 0.4688 - val_loss: 1.6250
# Epoch 18/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 460ms/step - accuracy: 0.5410 - loss: 1.4431 - val_accuracy: 0.4812 - val_loss: 1.6900
# Epoch 19/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 389ms/step - accuracy: 0.5279 - loss: 1.5195 - val_accuracy: 0.4437 - val_loss: 1.6446
# Epoch 20/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 376ms/step - accuracy: 0.5700 - loss: 1.3716 - val_accuracy: 0.5125 - val_loss: 1.4537
# Found 640 images belonging to 16 classes.
# Found 160 images belonging to 16 classes.
# Epoch 1/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 970ms/step - accuracy: 0.0880 - loss: 39.7586 - val_accuracy: 0.1688 - val_loss: 2.6041
# Epoch 2/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 473ms/step - accuracy: 0.1783 - loss: 2.5875 - val_accuracy: 0.2062 - val_loss: 2.4173
# Epoch 3/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 412ms/step - accuracy: 0.2930 - loss: 2.2252 - val_accuracy: 0.3250 - val_loss: 2.2848
# Epoch 4/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 433ms/step - accuracy: 0.3232 - loss: 2.1154 - val_accuracy: 0.2812 - val_loss: 2.2591
# Epoch 5/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 11s 445ms/step - accuracy: 0.3004 - loss: 2.1815 - val_accuracy: 0.2500 - val_loss: 2.2680
# Epoch 6/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 443ms/step - accuracy: 0.3305 - loss: 2.0644 - val_accuracy: 0.3750 - val_loss: 1.9714
# Epoch 7/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 383ms/step - accuracy: 0.4314 - loss: 1.7758 - val_accuracy: 0.4062 - val_loss: 2.1036
# Epoch 8/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 384ms/step - accuracy: 0.4512 - loss: 1.6920 - val_accuracy: 0.3063 - val_loss: 1.9874
# Epoch 9/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 384ms/step - accuracy: 0.4240 - loss: 1.7922 - val_accuracy: 0.3313 - val_loss: 2.2113
# Epoch 10/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 393ms/step - accuracy: 0.4215 - loss: 1.7954 - val_accuracy: 0.3438 - val_loss: 2.0805
# Epoch 11/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 372ms/step - accuracy: 0.4704 - loss: 1.6352 - val_accuracy: 0.4187 - val_loss: 1.9074
# Epoch 12/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 380ms/step - accuracy: 0.5212 - loss: 1.4958 - val_accuracy: 0.4500 - val_loss: 1.8027
# Epoch 13/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 381ms/step - accuracy: 0.4935 - loss: 1.4506 - val_accuracy: 0.4375 - val_loss: 1.9789
# Epoch 14/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 381ms/step - accuracy: 0.5628 - loss: 1.3489 - val_accuracy: 0.4688 - val_loss: 1.8206
# Epoch 15/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 382ms/step - accuracy: 0.5222 - loss: 1.3740 - val_accuracy: 0.4563 - val_loss: 1.6977
# Epoch 16/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 386ms/step - accuracy: 0.6343 - loss: 1.2173 - val_accuracy: 0.4187 - val_loss: 1.8671
# Epoch 17/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 394ms/step - accuracy: 0.5376 - loss: 1.3382 - val_accuracy: 0.5125 - val_loss: 1.8299
# Epoch 18/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 342ms/step - accuracy: 0.5538 - loss: 1.3336 - val_accuracy: 0.4500 - val_loss: 1.9495
# Epoch 19/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 400ms/step - accuracy: 0.6239 - loss: 1.1735 - val_accuracy: 0.4812 - val_loss: 1.7266
# Epoch 20/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 393ms/step - accuracy: 0.6260 - loss: 1.1860 - val_accuracy: 0.5000 - val_loss: 1.5923
